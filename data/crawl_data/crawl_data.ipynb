# %%
from bs4 import BeautifulSoup
import urllib.request

url =  'https://www.foody.vn/ha-noi/banh-mi-sot-vang-dinh-ngang/binh-luan'
page = urllib.request.urlopen(url)
soup = BeautifulSoup(page, 'html.parser')

# %%
temp = soup.find('body').find('div', id="FoodyApp").find('div', class_="pn-microsite").find('div', class_="micro-right1000").find('section', class_="microsite")

# %%
temp.find('div').find('div').find('div').find('div').find('div').find('div').find('div').find('script')
# Out:
# <script type="text/javascript">
#
# ...
